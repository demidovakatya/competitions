# %%
import pandas as pd

# %%
import os
data_folder = 'data'

# %%
opendata_files = [f for f in os.listdir(data_folder) if f.startswith('hospidiag_opendata')]

# %%
opendata_file = opendata_files[0]
pd.read_excel('/'.join([data_folder, opendata_file]))
# Out:
#                   axe                                           sous_axe  \
# 0    Carte d'identité                     Activité globale - Source PMSI
# 1    Carte d'identité                     Activité globale - Source PMSI
# 2    Carte d'identité                     Activité globale - Source PMSI
# 3    Carte d'identité                     Activité globale - Source PMSI
# 4    Carte d'identité                     Activité globale - Source PMSI
# 5    Carte d'identité                     Activité globale - Source PMSI
# 6    Carte d'identité                     Activité globale - Source PMSI
# 7    Carte d'identité                     Activité globale - Source PMSI
# 8    Carte d'identité                     Activité globale - Source PMSI
# 9    Carte d'identité                     Activité globale - Source PMSI
# 10   Carte d'identité                     Activité globale - Source PMSI
# 11   Carte d'identité                     Activité globale - Source PMSI
# ...
